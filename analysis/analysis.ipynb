# %%
import pandas as pd
import numpy as np
import requests
import json
import json
import math
import csv
import time
import matplotlib.pyplot as plt #sets up plotting under plt 
import seaborn as sns #sets up styles and gives us more plotting options 
from pyspark.sql.functions import col

# %%
colin_df = pd.read_csv('../dataGen/Colins-match-data.csv')
tim_df = pd.read_csv('../dataGen/Tims-match-data.csv')
colin = 'SKELETREX'
tim = 'liltimy'

# %%
tim_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4220 entries, 0 to 4219
# Data columns (total 43 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   match-id                4220 non-null   object
#  1   game-date               4220 non-null   int64
#  2   game-type               4220 non-null   object
#  3   assist-me-pings         4220 non-null   int64
#  4   enemy-missing-pings     4220 non-null   int64
#  5   bounty-level            4220 non-null   int64
#  6   ability-uses            0 non-null      float64
#  7   bounty-gold             4220 non-null   int64
#  8   buffs-stolen            4220 non-null   int64
#  9   control-wards-placed    4220 non-null   int64
#  10  damage-per-minute       4220 non-null   float64
#  11  damage-taken-on-team-%  4220 non-null   float64
#  12  deaths-by-enemy-champ   4220 non-null   int64
#  13  epic-monster-steals     4220 non-null   int64
#  14  first-turret-killed     4220 non-null   bool
#  15  gold-per-minute         4220 non-null   float64
#  16  kda                     4220 non-null   float64
#  17  assists                 4220 non-null   int64
#  18  turret-damage-dealt     4220 non-null   int64
#  19  vision-score            4220 non-null   int64
#  20  champ-name              4220 non-null   object
#  21  champ-level             4220 non-null   int64
#  22  deaths                  4220 non-null   int64
#  23  first-blood             4220 non-null   bool
#  24  first-blood-assist      4220 non-null   bool
#  25  gold-earned             4220 non-null   int64
#  26  gold-spent              4220 non-null   int64
#  27  individual-position     4220 non-null   object
#  28  inhibitors-lost         4220 non-null   int64
#  29  kills                   4220 non-null   int64
#  30  longest-time-alive      4220 non-null   int64
#  31  riot-id-game-name       4220 non-null   object
#  32  total-damage-dealt      4220 non-null   int64
#  33  total-time-spent-dead   4220 non-null   int64
#  34  team-id                 4220 non-null   int64
#  35  win                     4220 non-null   bool
#  36  game-duration           4220 non-null   int64
#  37  game-mode               4220 non-null   object
#  38  role                    4220 non-null   object
#  39  q-casts                 4220 non-null   int64
#  40  w-casts                 4220 non-null   int64
#  41  e-casts                 4220 non-null   int64
#  42  r-casts                 4220 non-null   int64
# dtypes: bool(4), float64(5), int64(27), object(7)
# memory usage: 1.3+ MB

# %%
teams = []
for index, row in tim_df.iterrows():
    if(row['riot-id-game-name'] == tim):
        teams.append(row['team-id'])

# %%
print(len(teams))
# Out:
# 422

# %%
col_team_df = pd.DataFrame()
for index, row in colin_df.iterrows():
    target_team = teams[int(index / 10)]
    if row['team-id'] == target_team:
#         if(row['riot-id-game-name'] != tim):
        col_team_df = col_team_df.append(row, ignore_index=True)
# Out:
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# /var/folders/hc/5nzbzlcj7pb0scr70pyzjxyh0000gn/T/ipykernel_2676/2203520562.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col_team_df = col_team_df.append(row, ignore_index=True)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [14], line 3
#       1 col_team_df = pd.DataFrame()
#       2 for index, row in colin_df.iterrows():
# ----> 3     target_team = teams[int(index / 10)]
#       4     if row['team-id'] == target_team:
#       5 #         if(row['riot-id-game-name'] != tim):
#       6         col_team_df = col_team_df.append(row, ignore_index=True)
#
# IndexError: list index out of range

# %%
col_team_df.to_csv("tims-teams.csv", index=False)
